# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt
from datetime import date, timedelta
from dateutil import relativedelta

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# establish connection
engine = create_engine("sqlite:///Facilities.sqlite")
conn = engine.connect()

# %%
# reflect an existing database into a new model
Base = automap_base()
Base.prepare(engine, reflect=True)

# reflect the tables
Base.metadata.tables #['LosAnglesCountyLicData']
# Out:
# immutabledict({'LosAnglesCountyLicData': Table('LosAnglesCountyLicData', MetaData(bind=None), Column('OSHPD_ID', INTEGER(), table=<LosAnglesCountyLicData>, primary_key=True, nullable=False), Column('FACILITY_NAME', TEXT(), table=<LosAnglesCountyLicData>), Column('LICENSE_NUM', INTEGER(), table=<LosAnglesCountyLicData>), Column('FACILITY_LEVEL_DESC', TEXT(), table=<LosAnglesCountyLicData>), Column('DBA_ADDRESS1', TEXT(), table=<LosAnglesCountyLicData>), Column('DBA_CITY', TEXT(), table=<LosAnglesCountyLicData>), Column('DBA_ZIP_CODE', INTEGER(), table=<LosAnglesCountyLicData>), Column('COUNTY_CODE', INTEGER(), table=<LosAnglesCountyLicData>), Column('COUNTY_NAME', TEXT(), table=<LosAnglesCountyLicData>), Column('ER_SERVICE_LEVEL_DESC', TEXT(), table=<LosAnglesCountyLicData>), Column('TOTAL_NUMBER_BEDS', INTEGER(), table=<LosAnglesCountyLicData>), Column('FACILITY_STATUS_DESC', TEXT(), table=<LosAnglesCountyLicData>), Column('FACILITY_STATUS_DATE', TEXT(), table=<LosAnglesCountyLicData>), Column('LICENSE_TYPE_DESC', TEXT(), table=<LosAnglesCountyLicData>), Column('LICENSE_CATEGORY_DESC', TEXT(), table=<LosAnglesCountyLicData>), Column('LATITUDE', REAL(), table=<LosAnglesCountyLicData>), Column('LONGITUDE', REAL(), table=<LosAnglesCountyLicData>), schema=None), 'encounters': Table('encounters', MetaData(bind=None), Column('year', INTEGER(), table=<encounters>, primary_key=True, nullable=False), Column('oshpd_id', INTEGER(), table=<encounters>, primary_key=True, nullable=False), Column('facility_name', TEXT(), table=<encounters>), Column('county_name', TEXT(), table=<encounters>), Column('er_service_level_desc', TEXT(), table=<encounters>), Column('type', TEXT(), table=<encounters>, primary_key=True, nullable=False), Column('count', INTEGER(), table=<encounters>), schema=None), 'hosp_la_df': Table('hosp_la_df', MetaData(bind=None), Column('FAC_NO', INTEGER(), table=<hosp_la_df>, primary_key=True, nullable=False), Column('FAC_NAME', TEXT(), table=<hosp_la_df>), Column('OP_STATUS', TEXT(), table=<hosp_la_df>), Column('TYPE_CNTRL', TEXT(), table=<hosp_la_df>), Column('TYPE_HOSP', TEXT(), table=<hosp_la_df>), Column('ZIP_CODE', INTEGER(), table=<hosp_la_df>), Column('STF_BEDS', INTEGER(), table=<hosp_la_df>), Column('DIS_TOT', INTEGER(), table=<hosp_la_df>), Column('DAY_TOT', INTEGER(), table=<hosp_la_df>), Column('VIS_TOT', INTEGER(), table=<hosp_la_df>), Column('GRIP_TOT', INTEGER(), table=<hosp_la_df>), Column('GROP_TOT', REAL(), table=<hosp_la_df>), Column('DED_TOT', INTEGER(), table=<hosp_la_df>), Column('CAP_TOT', INTEGER(), table=<hosp_la_df>), Column('NET_TOT', INTEGER(), table=<hosp_la_df>), Column('OTH_OP_REV', INTEGER(), table=<hosp_la_df>), Column('TOT_OP_EXP', INTEGER(), table=<hosp_la_df>), schema=None), 'hospitals': Table('hospitals', MetaData(bind=None), Column('OSHPD_ID', INTEGER(), table=<hospitals>, primary_key=True, nullable=False), Column('FACILITY_NAME', TEXT(), table=<hospitals>), Column('LICENSE_NUM', INTEGER(), table=<hospitals>), Column('FACILITY_LEVEL_DESC', TEXT(), table=<hospitals>), Column('DBA_ADDRESS1', TEXT(), table=<hospitals>), Column('DBA_CITY', TEXT(), table=<hospitals>), Column('DBA_ZIP_CODE', INTEGER(), table=<hospitals>), Column('COUNTY_CODE', INTEGER(), table=<hospitals>), Column('COUNTY_NAME', TEXT(), table=<hospitals>), Column('ER_SERVICE_LEVEL_DESC', TEXT(), table=<hospitals>), Column('TOTAL_NUMBER_BEDS', INTEGER(), table=<hospitals>), Column('FACILITY_STATUS_DESC', TEXT(), table=<hospitals>), Column('FACILITY_STATUS_DATE', TEXT(), table=<hospitals>), Column('LICENSE_TYPE_DESC', TEXT(), table=<hospitals>), Column('LICENSE_CATEGORY_DESC', TEXT(), table=<hospitals>), Column('LATITUDE', REAL(), table=<hospitals>), Column('LONGITUDE', REAL(), table=<hospitals>), Column('FAC_NO', INTEGER(), table=<hospitals>), Column('FAC_NAME', TEXT(), table=<hospitals>), Column('OP_STATUS', TEXT(), table=<hospitals>), Column('TYPE_CNTRL', TEXT(), table=<hospitals>), Column('TYPE_HOSP', TEXT(), table=<hospitals> ...

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['LosAnglesCountyLicData',
#  'encounters',
#  'hosp_la_df',
#  'hospitals',
#  'hospitals_avg_encounters']

# %%
# Save references to each table
Hospitals = Base.classes.hospitals
Licensed  = Base.classes.LosAnglesCountyLicData

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## Facitlities Analysis

# %%
# this methhod much more fun but might not work with all SQL syntaxes (but I prefer this way!)
query_stations = 'SELECT * FROM LosAnglesCountyLicData WHERE LICENSE_CATEGORY_DESC = "Community Clinic"'

# so easy to put it into a pandas dataframe!
df = pd.read_sql_query(query_stations, con=engine)
df
# Out:
#       OSHPD_ID                                      FACILITY_NAME  \
# 0    306174012                PLANNED PARENTHOOD BASICS, LAKEWOOD
# 1    306190007            TICHENOR ORTHOPEDIC CLINIC FOR CHILDREN
# 2    306190127         EISNER PEDIATRIC AND FAMILY MEDICAL CENTER
# 3    306190169                  SOUTH BAY CHILDRENS HEALTH CENTER
# 4    306190306  THE SABAN COMMUNITY CLINIC - BEVERLY HEALTH CE...
# ..         ...                                                ...
# 372  306198432  NORTHEAST VALLEY HEALTH CORPORATION - VAN NUYS...
# 373  306198476                         SERENITY CARE HEALTH GROUP
# 374  306198492                NOBLEQUEST HEALTH FOUNDATION CLINIC
# 375  306198494                                       VIA CARE 607
# 376  306274059                             GARFIELD HEALTH CENTER
#
#      LICENSE_NUM FACILITY_LEVEL_DESC         DBA_ADDRESS1       DBA_CITY  \
# 0      550001424     Parent Facility    5519 Del Amo Blvd       Lakewood
# 1      960000004     Parent Facility     1660 Termino Ave     Long Beach
# 2      960000030     Parent Facility      1530 S Olive St    Los Angeles
# 3      960000038     Parent Facility      410 CAMINO REAL  REDONDO BEACH
# 4      960000578     Parent Facility    8405 Beverly Blvd    Los Angeles
# ..           ...                 ...                  ...            ...
# 372    960000947     Parent Facility    14624 Sherman Way       Van Nuys
# 373    550003904     Parent Facility    2100 E Anaheim St     Long Beach
# 374    550003956     Parent Facility      14435 Hamlin St       Van Nuys
# 375    550003985     Parent Facility  607 S Atlantic Blvd    Los Angeles
# 376    960001453     Parent Facility   210 N Garfield Ave  Monterey Park
#
#      DBA_ZIP_CODE  COUNTY_CODE  COUNTY_NAME ER_SERVICE_LEVEL_DESC  \
# 0           90713           19  Los Angeles        Not Applicable
# 1           90804           19  Los Angeles        Not Applicable
# 2           90015           19  Los Angeles        Not Applicable
# 3           90277           19  Los Angeles        Not Applicable
# 4           90048           19  Los Angeles        Not Applicable
# ..            ...          ...          ...                   ...
# 372         91405           19  Los Angeles        Not Applicable
# 373         90804           19  Los Angeles        Not Applicable
# 374         91401           19  Los Angeles        Not Applicable
# 375         90022           19  Los Angeles        Not Applicable
# 376         91754           19  Los Angeles        Not Applicable
#
#     TOTAL_NUMBER_BEDS FACILITY_STATUS_DESC FACILITY_STATUS_DATE  \
# 0                None                 Open           11/18/2010
# 1                None                 Open            3/24/1947
# 2                None                 Open            3/23/1961
# 3                None                 Open            3/15/1954
# 4                None                 Open            10/8/1968
# ..                ...                  ...                  ...
# 372              None                 Open             5/9/2017
# 373              None                 Open            6/28/2017
# 374              None                 Open            8/14/2017
# 375              None                 Open           10/16/2017
# 376              None                 Open            11/2/2004
#
#     LICENSE_TYPE_DESC LICENSE_CATEGORY_DESC  LATITUDE  LONGITUDE
# 0              Clinic      Community Clinic  33.84714 -118.12431
# 1              Clinic      Community Clinic  33.78781 -118.14588
# 2              Clinic      Community Clinic  34.03540 -118.26522
# 3              Clinic      Community Clinic  33.83744 -118.38175
# 4              Clinic      Community Clinic  34.07608 -118.37347
# ..                ...                   ...       ...        ...
# 372            Clinic      Community Clinic  34.20115 -118.45170
# 373            Clinic      Community Clinic  33.78256 -118.16636
# 374            Clinic      Community Clinic  34.18869 -118.44771
# 375            Clinic      Community Clinic  34.02478 -118.15603
# 376            Clinic      Community Clinic  34.06418 -118.12283
#
# [377 rows x 17 columns]

# %% [markdown]
# ## Hospitals with ER Analysis

# %%
# this methhod much more fun but might not work with all SQL syntaxes (but I prefer this way!)
query_stations = 'SELECT * FROM LosAnglesCountyLicData WHERE LICENSE_TYPE_DESC = "Hospital" AND ER_SERVICE_LEVEL_DESC like "%Emergency%"'

# so easy to put it into a pandas dataframe!
df = pd.read_sql_query(query_stations, con=engine)
df
# Out:
#      OSHPD_ID                                      FACILITY_NAME  LICENSE_NUM  \
# 0   106190017                   ALHAMBRA HOSPITAL MEDICAL CENTER    930000005
# 1   106190034                           ANTELOPE VALLEY HOSPITAL    930000008
# 2   106190045                     CATALINA ISLAND MEDICAL CENTER    930000010
# 3   106190053               ST. MARY MEDICAL CENTER - LONG BEACH    930000012
# 4   106190066       LOS ANGELES COMMUNITY HOSPITAL AT BELLFLOWER    930000039
# ..        ...                                                ...          ...
# 69  106191231  LOS ANGELES COUNTY OLIVE VIEW-UCLA MEDICAL CENTER     60000133
# 70  106191450        KAISER FOUNDATION HOSPITAL - WOODLAND HILLS    930000358
# 71  106196035          KAISER FOUNDATION HOSPITAL - BALDWIN PARK    930000920
# 72  106196403                KAISER FOUNDATION HOSPITAL - DOWNEY    930000078
# 73  106196405                   PALMDALE REGIONAL MEDICAL CENTER    930000085
#
#       FACILITY_LEVEL_DESC             DBA_ADDRESS1        DBA_CITY  \
# 0         Parent Facility        100 S RAYMOND AVE        ALHAMBRA
# 1         Parent Facility             1600 W AVE J       LANCASTER
# 2         Parent Facility      100 FALLS CANYON RD          AVALON
# 3         Parent Facility          1050 Linden Ave      Long Beach
# 4   Consolidated Facility        9542 Artesia Blvd      Bellflower
# ..                    ...                      ...             ...
# 69        Parent Facility      14445 OLIVE VIEW DR          SYLMAR
# 70        Parent Facility         5601 DE SOTO AVE  WOODLAND HILLS
# 71        Parent Facility   1011 BALDWIN PARK BLVD    BALDWIN PARK
# 72        Parent Facility        9333 Imperial Hwy          Downey
# 73        Parent Facility  38600 Medical Center Dr        Palmdale
#
#     DBA_ZIP_CODE  COUNTY_CODE  COUNTY_NAME ER_SERVICE_LEVEL_DESC  \
# 0          91801           19  Los Angeles     Emergency - Basic
# 1          93534           19  Los Angeles     Emergency - Basic
# 2          90704           19  Los Angeles   Emergency - Standby
# 3          90813           19  Los Angeles     Emergency - Basic
# 4          90706           19  Los Angeles     Emergency - Basic
# ..           ...          ...          ...                   ...
# 69         91342           19  Los Angeles     Emergency - Basic
# 70         91367           19  Los Angeles     Emergency - Basic
# 71         91706           19  Los Angeles     Emergency - Basic
# 72         90242           19  Los Angeles     Emergency - Basic
# 73         93551           19  Los Angeles     Emergency - Basic
#
#     TOTAL_NUMBER_BEDS FACILITY_STATUS_DESC FACILITY_STATUS_DATE  \
# 0                 144                 Open             1/1/1946
# 1                 420                 Open            9/27/1955
# 2                  12                 Open             1/1/1946
# 3                 360                 Open             1/1/1946
# 4                 144                 Open            7/23/2015
# ..                ...                  ...                  ...
# 69                355                 Open           10/20/1959
# 70                274                 Open             4/8/1986
# 71                272                 Open            10/7/1998
# 72                352                 Open            8/31/2009
# 73                184                 Open            12/9/2010
#
#    LICENSE_TYPE_DESC        LICENSE_CATEGORY_DESC   LATITUDE   LONGITUDE
# 0           Hospital  General Acute Care Hospital  34.089880 -118.144900
# 1           Hospital  General Acute Care Hospital  34.687800 -118.157981
# 2           Hospital  General Acute Care Hospital  33.338870 -118.333690
# 3           Hospital  General Acute Care Hospital  33.780238 -118.186641
# 4           Hospital  General Acute Care Hospital  33.874720 -118.129450
# ..               ...                          ...        ...         ...
# 69          Hospital  General Acute Care Hospital  34.324180 -118.452550
# 70          Hospital  General Acute Care Hospital  34.171980 -118.588290
# 71          Hospital  General Acute Care Hospital  34.063480 -117.986000
# 72          Hospital  General Acute Care Hospital  33.917123 -118.129022
# 73          Hospital  General Acute Care Hospital  34.584375 -118.144346
#
# [74 rows x 17 columns]

# %% [markdown]
# ## Encounters Analysis

# %%
# this methhod much more fun but might not work with all SQL syntaxes (but I prefer this way!)
query_stations = 'SELECT * FROM encounters'

# so easy to put it into a pandas dataframe!
df = pd.read_sql_query(query_stations, con=engine)
df
# Out:
#       year   oshpd_id                                      facility_name  \
# 0     2012  106190017                   ALHAMBRA HOSPITAL MEDICAL CENTER
# 1     2012  106190017                   ALHAMBRA HOSPITAL MEDICAL CENTER
# 2     2012  106190034                           ANTELOPE VALLEY HOSPITAL
# 3     2012  106190034                           ANTELOPE VALLEY HOSPITAL
# 4     2012  106190045                     CATALINA ISLAND MEDICAL CENTER
# ...    ...        ...                                                ...
# 1083  2018  106196168  MEMORIALCARE MILLER CHILDREN'S & WOMEN'S HOSPI...
# 1084  2018  106196403                KAISER FOUNDATION HOSPITAL - DOWNEY
# 1085  2018  106196403                KAISER FOUNDATION HOSPITAL - DOWNEY
# 1086  2018  106196405                   PALMDALE REGIONAL MEDICAL CENTER
# 1087  2018  106196405                   PALMDALE REGIONAL MEDICAL CENTER
#
#       county_name er_service_level_desc      type    count
# 0     LOS ANGELES                 BASIC  ED_Admit   2603.0
# 1     LOS ANGELES                 BASIC  ED_Visit  10263.0
# 2     LOS ANGELES                 BASIC  ED_Admit  13234.0
# 3     LOS ANGELES                 BASIC  ED_Visit  91791.0
# 4     LOS ANGELES               STANDBY  ED_Admit     15.0
# ...           ...                   ...       ...      ...
# 1083  LOS ANGELES                  None  ED_Visit      NaN
# 1084  LOS ANGELES                 BASIC  ED_Admit   8038.0
# 1085  LOS ANGELES                 BASIC  ED_Visit  97457.0
# 1086  LOS ANGELES                 BASIC  ED_Admit   6607.0
# 1087  LOS ANGELES                 BASIC  ED_Visit  64603.0
#
# [1088 rows x 7 columns]

# %% [markdown]
# ## Avg Encounters Analysis

# %%
# this methhod much more fun but might not work with all SQL syntaxes (but I prefer this way!)
query_stations = 'SELECT * FROM hospitals_avg_encounters'

# so easy to put it into a pandas dataframe!
df = pd.read_sql_query(query_stations, con=engine)
df
# Out:
#      OSHPD_ID                                           FAC_NAME  \
# 0   106190017                   ALHAMBRA HOSPITAL MEDICAL CENTER
# 1   106190034                           ANTELOPE VALLEY HOSPITAL
# 2   106190045                     CATALINA ISLAND MEDICAL CENTER
# 3   106190053               ST. MARY MEDICAL CENTER - LONG BEACH
# 4   106190081                                   BEVERLY HOSPITAL
# ..        ...                                                ...
# 72  106194219                               KECK HOSPITAL OF USC
# 73  106196035          KAISER FOUNDATION HOSPITAL - BALDWIN PARK
# 74  106196168  MEMORIALCARE MILLER CHILDREN'S & WOMEN'S HOSPI...
# 75  106196403                KAISER FOUNDATION HOSPITAL - DOWNEY
# 76  106196405                   PALMDALE REGIONAL MEDICAL CENTER
#
#                DBA_ADDRESS1      DBA_CITY  DBA_ZIP_CODE ER_SERVICE_LEVEL_DESC  \
# 0         100 S RAYMOND AVE      ALHAMBRA         91801     Emergency - Basic
# 1              1600 W AVE J     LANCASTER         93534     Emergency - Basic
# 2       100 FALLS CANYON RD        AVALON         90704   Emergency - Standby
# 3           1050 Linden Ave    Long Beach         90813     Emergency - Basic
# 4        309 W BEVERLY BLVD    MONTEBELLO         90640     Emergency - Basic
# ..                      ...           ...           ...                   ...
# 72        1500 SAN PABLO ST   LOS ANGELES         90033                  None
# 73   1011 BALDWIN PARK BLVD  BALDWIN PARK         91706     Emergency - Basic
# 74        2801 Atlantic Ave    Long Beach         90806                  None
# 75        9333 Imperial Hwy        Downey         90242     Emergency - Basic
# 76  38600 Medical Center Dr      Palmdale         93551     Emergency - Basic
#
#     TOTAL_NUMBER_BEDS   LATITUDE   LONGITUDE        TYPE_CNTRL     NET_TOT  \
# 0                 144  34.089880 -118.144900  Investor - Ptnr.   192170249
# 1                 420  34.687800 -118.157981          District   442828351
# 2                  12  33.338870 -118.333690  Non Profit Corp.     9724231
# 3                 360  33.780238 -118.186641  Non Profit Corp.   352700261
# 4                 202  34.016140 -118.101320  Non Profit Corp.   179845974
# ..                ...        ...         ...               ...         ...
# 72                401  34.062840 -118.202870  Investor - Corp.  1178217757
# 73                272  34.063480 -117.986000  Non Profit Corp.   137703960
# 74                357  33.808070 -118.185060  Non Profit Corp.   495886562
# 75                352  33.917123 -118.129022  Non Profit Corp.   188443936
# 76                184  34.584375 -118.144346  Investor - Corp.   193681752
#
#    er_service_level  AvgAdmits  AvgVisits
# 0             BASIC    3131.57   13445.71
# 1             BASIC   12443.29  105222.29
# 2           STANDBY       8.43    1916.86
# 3             BASIC    6538.29   48016.43
# 4             BASIC    6743.14   28261.43
# ..              ...        ...        ...
# 72             None       1.00        NaN
# 73            BASIC    6265.57   73186.14
# 74             None       1.00        NaN
# 75            BASIC    9002.86   86981.86
# 76            BASIC    6809.00   60066.29
#
# [77 rows x 14 columns]
